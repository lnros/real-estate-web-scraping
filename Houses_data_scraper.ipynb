# %%
from dateutil import parser
import datetime
import re
from bs4 import BeautifulSoup as bs
import requests
import json
import pandas as pd
import time

# %% [markdown]
# ### Getting the regions list for sales and rent

# %%
# Load the webpage
webpage_path = 'https://www.onmap.co.il/en'

r = requests.get(webpage_path)

# Convert to a beautiful soup object
soup = bs(r.content)

# Getting the URLs list of regions for sale
buy_urls = []
for url in soup.find_all("input", {"type" : "radio",'name':"home-page-cities-links","value" : re.compile(".*/buy/\w+.*")}):
    buy_urls.append(webpage_path+url['value'])

# Getting the URLs list of regions for rent
rent_urls = []
for url in soup.find_all("input", {"type" : "radio",'name':"home-page-cities-links","value" : re.compile(".*/rent/\w+.*")}):
    rent_urls.append(webpage_path+url['value'])

# %% [markdown]
# ### Getting the sales data per region from the webserver

# %%
sales_per_region_database_list = []
for url in buy_urls:
    region_name = url.split('/')[-1]
    sales_per_region_database_list.append(f'https://phoenix.onmap.co.il/v1/properties/mixed_search?option=buy&section=residence&city={region_name}&$sort=-is_top_promoted+-search_date')

# %% [markdown]
# ### Getting the rent data per region from the webserver

# %%
rent_per_region_database_list = []
for url in rent_urls:
    region_name = url.split('/')[-1]
    rent_per_region_database_list.append(f'https://phoenix.onmap.co.il/v1/properties/mixed_search?option=rent&section=residence&city={region_name}&$sort=-is_top_promoted+-search_date')

# %% [markdown]
# ### columns_names for rent_data_frame

# %%
columns_names = ['Date', 'City_name', 'Street_name', 'House_number', 'Bathrooms', 'Rooms', 'Floor', 'Area[m^2]', 'Parking_spots_aboveground', 'Parking_spots_underground', 'Price[NIS]', 'Property_type']

# %% [markdown]
# ### Scraper

# %%
rent_df = pd.DataFrame(columns=columns_names)
for region in rent_per_region_database_list:
    r = requests.get(region)
    time.sleep(2)
    soup = bs(r.content)
    apartment_dict_list = json.loads(soup.p.get_text())['data']
    ff = 0
    for apartment_dict in apartment_dict_list:
        ff += 1
        df_row = {'Date' : [parser.parse(apartment_dict['created_at']).date()],
                   'City_name' : [apartment_dict['address']['en']['city_name']],
                   'Street_name': [apartment_dict['address']['en']['street_name']],
                   'House_number': [apartment_dict['address']['en']['house_number']],
                   'Bathrooms': [apartment_dict['additional_info']['bathrooms']],
                   'Rooms' : [apartment_dict['additional_info']['rooms']],
                   'Floor' : [apartment_dict['additional_info']['floor']['on_the']],
                   'Area[m^2]' : [apartment_dict['additional_info']['area']['base']],
                   'Parking_spots_aboveground' : [apartment_dict['additional_info'].get('parking', {}).get('aboveground')],
                   'Parking_spots_underground' : [apartment_dict['additional_info'].get('parking', {}).get('underground')],
                   'Price[NIS]' : [apartment_dict['price']],
                   'Property_type' : [apartment_dict['property_type']]
                 }
        rent_df = pd.concat([rent_df, pd.DataFrame(df_row)])
        if ff == 3: 
            break

# %% [markdown]
# ### Reset the Index

# %%
rent_df.reset_index(drop=True, inplace=True)

# %%
rent_df
# Out:
#           Date        City_name              Street_name House_number  \
# 0   2021-02-03    Tel Aviv-Yafo                Geula St.         None
# 1   2020-11-25    Tel Aviv-Yafo         Nissim Aloni St.           10
# 2   2021-02-15    Tel Aviv-Yafo                  Mor St.           10
# 3   2021-01-21          Netanya        Pierre Koenig St.           11
# 4   2020-12-25          Netanya   HaRav Yosef Rivlin St.            8
# 5   2020-02-26          Netanya          Nitsa Boulevard           20
# 6   2020-12-02  Rishon LeTsiyon             HaLevana St.            5
# 7   2020-08-11  Rishon LeTsiyon              HaSadeh St.         None
# 8   2020-09-27  Rishon LeTsiyon  Rabi Yehuda ha-Nasi St.           23
# 9   2020-12-17          Rehovot        Moshe Mizrahi St.            6
# 10  2019-06-13          Rehovot    Rachel Hirshenzon St.         None
# 11  2020-05-10          Rehovot               Sderot Hen         None
# 12  2020-07-08            Haifa            Leon Blum St.           54
# 13  2021-01-06            Haifa          Rabbi Akiva St.            7
# 14  2020-10-23            Haifa         Yehuda Burla St.           23
# 15  2021-02-09           Ashdod               Rambam St.            9
# 16  2021-01-16           Ashdod         Ha-Histadrut St.           11
# 17  2021-01-16           Ashdod        Shavei Tsiyon St.           28
# 18  2021-01-17            Holon                Eilat St.           10
# 19  2020-02-25            Holon         Ekhad be-Mai St.         None
# 20  2020-02-20            Holon               Geulim St.           40
# 21  2021-01-26          Bat Yam              Masaryk St.         None
# 22  2021-02-07          Bat Yam              Balfour St.         None
# 23  2019-06-05          Bat Yam             HaShikma St.            4
# 24  2021-01-20      Petah Tikva           Rothschild St.         None
# 25  2021-01-21      Petah Tikva           Bar Kochva St.         None
# 26  2021-01-25      Petah Tikva            Ha-Atsmon St.         None
#
#    Bathrooms Rooms Floor Area[m^2] Parking_spots_aboveground  \
# 0          2     4     2       100                      none
# 1          1     3    10        75                      none
# 2          1     3     1        70                      None
# 3          2     4     7       117                      none
# 4          1     3     2       100                      none
# 5          2     4    17       147                      none
# 6          1     2     0        35                      None
# 7          2   3.5     3        80                         1
# 8          1     5     2       129                         2
# 9          1     3     2        70                      None
# 10         1     2     4        40                      None
# 11         1     3     2        60                      None
# 12         2   3.5     9        85                      none
# 13         1   2.5     1        75                      None
# 14         1     3     3        70                      None
# 15         1   2.5     3        48                      None
# 16         1     3     1        62                      None
# 17         1     4     2       110                      none
# 18         1     2     3        40                      None
# 19         1     2     1        68                      None
# 20         1     3     4        70                      none
# 21         1     3     8        85                         1
# 22         2     3     8        70                      None
# 23         1     3     3        88                      none
# 24         1     2     1        50                      None
# 25         1     1     0        15                      None
# 26         2     3     4        75                      None
#
#    Parking_spots_underground Price[NIS] Property_type
# 0                          1      13500     apartment
# 1                          2       7999     apartment
# 2                       None       3800     apartment
# 3                          1       6000     apartment
# 4                       none       3800     apartment
# 5                          2       8000     apartment
# 6                       None       3000  housing_unit
# 7                       none       4500     apartment
# 8                       none       7000     apartment
# 9                       None       3300     apartment
# 10                      None       2800     apartment
# 11                      None       4000     apartment
# 12                      none       3300     apartment
# 13                      None       2300     apartment
# 14                      None       2800     apartment
# 15                      None       3300     apartment
# 16                      None       3600     apartment
# 17                      none       3900     apartment
# 18                      None       3800     apartment
# 19                      None       4000     apartment
# 20                      none       3700     apartment
# 21                      none       5500     apartment
# 22                      None       5500     apartment
# 23                      None       3900     apartment
# 24                      None       3500     apartment
# 25                      None       2200     apartment
# 26                      None       3500     apartment

# %% [markdown]
# ### Writing the renting data to csv

# %%
with open("Renting_data.csv",'w') as f:
    rent_df.to_csv(f, header=rent_df.columns, index=False, line_terminator='\n')
